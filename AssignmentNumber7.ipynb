# %% [markdown]
# # Assignment 7

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Question 1a

# %% [markdown]
# Describe, with a concrete example (e.g. a spiral or a rolled manifold), why a linear projection can fail to separate clusters that a nonlinear method would resolve.

# %% [markdown]
# The Principal Component Analysis (PCA) assumes linearity
#
# The Objective function for principle component analisys is quadratic.
#
# It finds the first principal component by solving for a unit vector $\mathbf{w}$ that maximizes the variance of the projected data $\mathbf{X}\mathbf{w}$.
#
# The reconstruction formulas is also clear proofs that principle component analisys in linear operation.

# %% [markdown]
# #### Question 1b

# %% [markdown]
# State the key property that t-SNE (t-distributed Stochastic Neighbor Embedding) tries to preserve, and contrast it with the property that
# PCA maximizes.

# %% [markdown]
# t-sne uses local neighborhood structure.
#
#
# PCA maximizes the global variance. It finds orthogonal directions (principal components) that capture the maximum spread of the data
